# %% [markdown]
# # 00 Dataset Readiness
#
# Checks the public-data inputs used to calibrate the streaming ad and recommendation-marketplace cases.

# %%
from pathlib import Path
import sys

CODE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(CODE_DIR))

from src.config import ensure_artifact_dirs
from src.data import dataset_readiness, inspect_kuairand_archive
from src.tables import write_table

ensure_artifact_dirs()
readiness = dataset_readiness()
write_table(readiness, '00_dataset_readiness.csv')
archive = inspect_kuairand_archive()
if len(archive):
    write_table(archive, '00_kuairand_archive_manifest.csv')
readiness
# Out:
#                   dataset                                               path  \
# 0           criteo_uplift  /home/apex/Documents/ranking_sys/data/criteo/c...
# 1       kuairec_processed  /home/apex/Documents/ranking_sys/data/processe...
# 2       kuairec_long_term  /home/apex/Documents/ranking_sys/data/processe...
# 3        kuairand_archive  /home/apex/Documents/ranking_sys/data/KuaiRand...
# 4  open_bandit_random_men  /home/apex/Documents/ranking_sys/data/processe...
#
#    exists    size_mb
# 0    True    311.423
# 1    True      1.144
# 2    True      0.355
# 3    True  11075.061
# 4    True      2.165
