# %% [markdown]
# # 04 Appendix: Geometry and Calibration Diagnostics
#
# Tests the sharp support-function theorem and the high-dimensional separation theorem: support-function equality, signed-hull characterization, split-conformal coverage, and high-dimensional separation from generic residual calibration.

# %%
from pathlib import Path
import sys

CODE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(CODE_DIR))

from src.figures import plot_support_characterization, plot_theory_geometry
from src.tables import write_table
from src.theory_checks import conformal_coverage_check, high_dimensional_separation_grid, sharp_support_function_check, support_function_characterization_check

sharp = sharp_support_function_check()
characterization = support_function_characterization_check()
coverage = conformal_coverage_check()
separation = high_dimensional_separation_grid()
write_table(sharp, '04_support_function_sharpness.csv')
write_table(characterization, '04_support_function_characterization.csv')
write_table(coverage, '04_conformal_coverage.csv')
write_table(separation, '04_high_dimensional_separation.csv')
plot_theory_geometry(separation, coverage, 'appendix_theory_geometry.png')
plot_support_characterization(characterization, 'appendix_support_characterization.png')
sharp, characterization, coverage, separation.head()
# Out:
# /home/apex/Documents/ranking_sys/notebooks/writing/forecast_calibrated_causal_pacing_yield_optimization_streaming_ads/code/src/figures.py:16: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# (                  check  max_abs_gap  violation_rate
#  0      support_equality     0.000000             0.0
#  1  minimality_violation     3.049801             1.0,
#                    certificate   set_relation_to_signed_hull  \
#  0         minimal_signed_hull          equal_to_signed_hull
#  1            l2_ball_superset               strict_superset
#  2     coordinate_box_superset               strict_superset
#  3  missing_active_sensitivity  does_not_contain_signed_hull
#  4         understated_support      scaled_below_signed_hull
#
#     contains_signed_sensitivities  is_support_function_certificate  \
#  0                           True                             True
#  1                           True                             True
# ...
